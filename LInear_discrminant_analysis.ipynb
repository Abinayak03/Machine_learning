# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinayak03/Machine_learning/blob/main/LInear_discrminant_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_wine
data_wine=load_wine()

# %%
ind=data_wine.data
tar=data_wine.target

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda_transformed=lda.fit_transform(ind,tar)

# %%
lda.explained_variance_ratio_
# Out:
# array([0.68747889, 0.31252111])

# %%
import matplotlib.pyplot as plt
plt.xlabel('LDA1')
plt.ylabel('LDA2')
plt.scatter(lda_transformed[:,0],lda_transformed[:,1],c=tar)
plt.show()
